# %% [markdown]
# ## Project Objectives
# 1. Import Important Libraries
# 2. Define Connection Parameters(To the Database)
# 3. Define Connection String
# 4. Establish Connection
# 5. Close Connection
# 6. Make Visualization
# 7. Save Figure(Visualization)

# %% [markdown]
# ###  Import  Libraries

# %%
import pandas as pd
import seaborn as sns
import pyodbc 
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### Connection to the Database

# %%
server = 'DESKTOP-U507UFU'
database = 'PRACTICE'
conn_str = (
    "Driver= {SQL Server};"
    f"Server={Server};"
    f"Database={Database};"
    "Trusted_Connection=yes;"    
)
conn = pyodbc.connect(conn_str)

# %%
query = """
             SELECT 
        concert_id,
        tickets_sold,
        city,
        sponsor,
        label,
        	artist_name,
            ticket_price_avg,
        	genre,
        	concert_revenue,
            profit
        FROM concerts AS c1 
        WHERE concert_revenue =(
        	SELECT MAX (concert_revenue)
        	FROM concerts AS c2
             WHERE c1.genre = c2.genre
       
        )
         ORDER BY concert_revenue DESC        
        ;
"""

# %%
df = pd.read_sql(query, conn)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19544\1168034203.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %% [markdown]
# ## Data Inpsection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   concert_id        5 non-null      int64
#  1   tickets_sold      5 non-null      object
#  2   city              5 non-null      object
#  3   sponsor           5 non-null      object
#  4   label             5 non-null      object
#  5   artist_name       5 non-null      object
#  6   ticket_price_avg  5 non-null      object
#  7   genre             5 non-null      object
#  8   concert_revenue   5 non-null      float64
#  9   profit            5 non-null      object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#        concert_id  concert_revenue
# count    5.000000         5.000000
# mean    36.000000    792936.806000
# std     18.425526    133540.920734
# min     10.000000    638938.120000
# 25%     30.000000    654919.010000
# 50%     33.000000    881544.540000
# 75%     50.000000    890812.810000
# max     57.000000    898469.550000

# %%
df.shape
# Out:
# (5, 10)

# %%
df.head(20)
# Out:
#    concert_id tickets_sold         city    sponsor                    label  \
# 0          57        44045       London      Pepsi            Big Hit Music
# 1          50        49895        Tokyo       Nike               XO Records
# 2          30        46583  Los Angeles  Coca-Cola         Republic Records
# 3          33        62482       London      Apple  Aftermath Entertainment
# 4          10        72815     New York      Pepsi         Columbia Records
#
#      artist_name ticket_price_avg    genre  concert_revenue      profit
# 0            BTS            76.44    K-Pop        898469.55  1027459.95
# 1     The Weeknd           197.11  R&B/Pop        890812.81   929261.36
# 2  Ariana Grande           185.78      Pop        881544.54   740348.36
# 3         Eminem           134.49  Hip-Hop        654919.01   680193.93
# 4        Beyonce           240.48      R&B        638938.12   541806.42

# %% [markdown]
# ### Top 5 Perfoming Concerts by Concert Revenue

# %%
Top5 = df.head(10).copy()

# %%
Top5['concert_id'] = Top5['concert_id'].astype(str)
plt.figure(figsize = (8,4))
sns.lineplot(
    data = Top5,
    x = 'concert_id',
    y= 'concert_revenue',   
)
plt.title('Top Perfoming Concerts', fontweight= 'bold')
plt.xlabel('Concert Ids')
plt.ylabel('Total Concert Revenues')
# Out:
# Text(0, 0.5, 'Total Concert Revenues')

# %%
Top5['concert_id'] = Top5['concert_id'].astype(str)
plt.figure(figsize = (8,4))
colors = sns.color_palette("Blues", len(Top5))
sns.barplot(
    data = Top5,
    x = 'concert_id',
    palette =colors[::-1],
    y= 'concert_revenue',
    hue = 'concert_id',
)
plt.title('Top Perfoming Concerts', fontweight= 'bold')
plt.xlabel('Concert Ids')
plt.ylabel('Total Concert Revenues')
plt.savefig("Top-Perfoming Concerts.png", bbox_inches = 'tight', dpi = 300)
plt.tight_layout()
plt.show()

# %%
Top5.to_csv("Top5_concerts.csv", index =False)

# %%
print(os.getcwd())
# Out:
# D:\SQL  PRACTICE\music_concert
